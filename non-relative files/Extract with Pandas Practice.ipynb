# %%
import pandas as pd

tables = pd.read_html('https://www.fatsecret.com/calories-nutrition/food/snacks')
len(tables)
# Out:
# 15

# %%
tables[3]
# Out:
#                               Popular Types of Snacks  \
# 0                      Sweet Snacks (1 snack serving)
# 1                                               Apple
# 2                   Chocolate Creme Filled Snack Cake
# 3                     Chocolate Chip Crisped Rice Bar
# 4                                              Cookie
# 5                                            Doughnut
# 6                                    Hard Granola Bar
# 7                                   Leather Fruit Bar
# 8                                            Licorice
# 9                            Milk Chocolate Candy Bar
# 10                            Soft Raisin Granola Bar
# 11                                              Taffy
# 12              Savory or Salty Snacks (1 oz serving)
# 13                                 Air Popped Popcorn
# 14                                       Banana Chips
# 15                                         Beef Jerky
# ...

# %%
df = tables[3]
df
# Out:
#                               Popular Types of Snacks  \
# 0                      Sweet Snacks (1 snack serving)
# 1                                               Apple
# 2                   Chocolate Creme Filled Snack Cake
# 3                     Chocolate Chip Crisped Rice Bar
# 4                                              Cookie
# 5                                            Doughnut
# 6                                    Hard Granola Bar
# 7                                   Leather Fruit Bar
# 8                                            Licorice
# 9                            Milk Chocolate Candy Bar
# 10                            Soft Raisin Granola Bar
# 11                                              Taffy
# 12              Savory or Salty Snacks (1 oz serving)
# 13                                 Air Popped Popcorn
# 14                                       Banana Chips
# 15                                         Beef Jerky
# ...

# %%
df.drop(index=[0,12,27],inplace=True)
df
# Out:
#               Popular Types of Snacks Fat(g) Carbs(g) Prot(g) Calories
# 1                               Apple   0.23    19.06    0.36       72
# 2   Chocolate Creme Filled Snack Cake   7.25    30.15    1.70      188
# 3     Chocolate Chip Crisped Rice Bar   3.78    20.44    1.43      113
# 4                              Cookie   2.14     6.90    0.54       49
# 5                            Doughnut  10.51    21.62    2.62      190
# 6                    Hard Granola Bar   4.95    16.10    2.52      118
# 7                   Leather Fruit Bar   1.22    18.06    0.41       81
# 8                            Licorice   0.01    10.29       -       41
# 9            Milk Chocolate Candy Bar  13.05    26.14    3.37      235
# 10            Soft Raisin Granola Bar   7.65    28.55    3.27      193
# 11                              Taffy   0.89     9.20    0.09       44
# 13                 Air Popped Popcorn   1.29    22.05    3.67      110
# ...

# %%
cols = df.columns

for col in cols:
    print(f'{col}:\n')
    print(df[col].value_counts())
# Out:
# Popular Types of Snacks:
#
# Apple                                1
# Beef Jerky                           1
# Tortilla Chips                       1
# Salted Potato Chips                  1
# Peanuts                              1
# Mixed Nuts                           1
# Hard Pretzels                        1
# Crackers                             1
# Corn Chips                           1
# Cheese Puffs                         1
# Cheese Flavor Popcorn                1
# Brown Rice Cakes                     1
# Banana Chips                         1
# Chocolate Creme Filled Snack Cake    1
# Air Popped Popcorn                   1
# Taffy                                1
# Soft Raisin Granola Bar              1
# Milk Chocolate Candy Bar             1
# Licorice                             1
# Leather Fruit Bar                    1
# Hard Granola Bar                     1
# Doughnut                             1
# Cookie                               1
# ...

# %%
df['Prot(g)'] = df['Prot(g)'].replace('-',0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 26
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Popular Types of Snacks  25 non-null     object
#  1   Fat(g)                   25 non-null     object
#  2   Carbs(g)                 25 non-null     object
#  3   Prot(g)                  25 non-null     object
#  4   Calories                 25 non-null     object
# dtypes: object(5)
# memory usage: 1.2+ KB

# %%
floats = {
    'Fat(g)':float,
    'Carbs(g)':float,
    'Prot(g)':g
}
# Out:
#        Popular Types of Snacks Fat(g) Carbs(g) Prot(g) Calories
# count                       25     25       25      25       25
# unique                      25     25       25      25       23
# top                      Apple   0.23    19.06    0.36      110
# freq                         1      1        1       1        2
